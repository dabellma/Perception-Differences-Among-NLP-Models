# %% [markdown]
# # Perception Difference Among NLP Models

# %%
import sys
# !{sys.executable} -m pip install dynet
# Out:
# Requirement already satisfied: dynet in c:\users\marky\anaconda3\lib\site-packages (2.1.2)
# Requirement already satisfied: numpy in c:\users\marky\anaconda3\lib\site-packages (from dynet) (1.20.1)
# Requirement already satisfied: cython in c:\users\marky\anaconda3\lib\site-packages (from dynet) (0.29.23)

# %%
from collections import defaultdict
import time
import random

import dynet_config
import dynet as dy

import numpy as np

# %%
# Functions to read in the corpus
w2i = defaultdict(lambda: len(w2i))
t2i = defaultdict(lambda: len(t2i))
UNK = w2i["<unk>"] # create an index for the unknown token
def read_dataset(filename):
    with open(filename, "r") as f:
        for line in f:
            tag, words = line.lower().strip().split(" ||| ")
            yield ([w2i[x] for x in words.split(" ")], t2i[tag])

# %%
# Read in the data
train_set = list(read_dataset("dist_semantics_lecture_movie_review_data/train.txt"))
w2i = defaultdict(lambda: UNK, w2i) # put unknown index on the front
dev_set = list(read_dataset("dist_semantics_lecture_movie_review_data/test.txt"))
nwords = len(w2i)
ntags = len(t2i)

# %%
nwords, ntags
# Out:
# (18648, 5)

# %%
len(train_set), len(dev_set)
# Out:
# (8544, 2210)

# %%
nwords
# Out:
# 18648

# %%
len(w2i),w2i # words to indices
# Out:
# (18648,
#  defaultdict(<function __main__.<lambda>()>,
#              {'<unk>': 0,
#               'the': 1,
#               'rock': 2,
#               'is': 3,
#               'destined': 4,
#               'to': 5,
#               'be': 6,
#               '21st': 7,
#               'century': 8,
#               "'s": 9,
#               'new': 10,
#               '``': 11,
#               'conan': 12,
#               "''": 13,
#               'and': 14,
#               'that': 15,
#               'he': 16,
#               'going': 17,
#               'make': 18,
#               'a': 19,
#               'splash': 20,
#               'even': 21,
#               'greater': 22,
#               'than': 23,
#               'arnold': 24,
#               'schwarzenegger': 25,
#               ',': 26,
#               'jean-claud': 27,
#               'van': 28,
#               'damme': 29,
#               'or': 30,
#               'steven': 31,
#               'segal': 32,
#               '.': 33,
#               'gorgeously': 34,
#               'elaborate': 35,
#               'continuation': 36,
#               'of': 37,
#               'lord': 38,
#               'rings': 39,
#               'trilogy': 40,
#               'so': 41,
#               'huge': 42,
#               'column': 43,
#               'words': 44,
#               'can': 45,
#               'not': 46,
#               'adequately': 47,
#               'describe': 48,
#               'co-writer\\/director': 49,
#               'peter': 50,
#               'jackson': 51,
#               'expanded': 52,
#               'vision': 53,
#               'j.r.r.': 54,
#               'tolkien': 55,
#               'middle-earth': 56,
#               'singer\\/composer': 57,
#               'bryan': 58,
#               'adams': 59,
#               'contributes': 60,
#               'slew': 61,
#               'songs': 62,
#               '--': 63,
#               'few': 64,
#               'potential': 65,
#               'hits': 66,
#               'more': 67,
#               'simply': 68,
#               'intrusive': 69,
#               'story': 70,
#               'but': 71,
#               'whole': 72,
#               'package': 73,
#               'certainly': 74,
#               'captures': 75,
#               'intended': 76,
#               'er': 77,
#               'spirit': 78,
#               'piece': 79,
#               'you': 80,
#               "'d": 81,
#               'think': 82,
#               'by': 83,
#               'now': 84,
#               'america': 85,
#               'would': 86,
#               'have': 87,
#               'had': 88,
#               'enough': 89,
#               'plucky': 90,
#               'british': 91,
#               'eccentrics': 92,
#               'with': 93,
#               'hearts': 94,
#               'gold': 95,
#               'yet': 96,
#               'act': 97,
#               'still': 98,
#               'charming': 99,
#               'here': 100,
#               'whether': 101,
#               "'re": 102,
#               'enlightened': 103,
#               'any': 104,
#               'derrida': 105,
#               'lectures': 106,
#               'on': 107,
#               'other': 108,
#               'self': 109,
#               'an': 110,
#               'undeniably': 111,
#               'fascinating': 112,
#               'playful': 113,
#               'fellow': 114,
#               'just': 115,
#               'labour': 116,
#               'involved': 117,
#               'in': 118,
#               'creating': 119,
#               'layered': 120,
#               'richness': 121,
#               'imagery': 122,
#               'this': 123,
#               'chiaroscuro': 124,
#               'madness': 125,
#               'light': 126,
#               'astonishing': 127,
#               'part': 128,
#               'charm': 129,
#               'satin': 130,
#               'rouge': 131,
#               'it': 132,
#               'avoids': 133,
#               'obvious': 134,
#               'humour': 135,
#               'lightness': 136,
#               'screenplay': 137,
#               'ingeniously': 138,
#               'constructed': 139,
#               'memento': 140,
#               'extreme': 141,
#               'ops': 142,
#               'exceeds': 143,
#               'expectations': 144,
#               'good': 145,
#               'fun': 146,
#               'action': 147,
#               'acting': 148,
#               'dialogue': 149,
#               'pace': 150,
#               'cinematography': 151,
#               'should': 152,
#               'pay': 153,
#               'nine': 154,
#               'bucks': 155,
#               'for': 156,
#               ':': 157,
#               'because': 158,
#               'hear': 159,
#               'about': 160,
#               'suffering': 161,
#               'afghan': 162,
#               'refugees': 163,
#               'news': 164,
#               'unaffected': 165,
#               'dramas': 166,
#               'like': 167,
#               'human': 168,
#               'thunderous': 169,
#               'ride': 170,
#               'at': 171,
#               'first': 172,
#               'quiet': 173,
#               'cadences': 174,
#               'pure': 175,
#               'finesse': 176,
#               'are': 177,
#               'far': 178,
#               'between': 179,
#               ';': 180,
#               'their': 181,
#               'shortage': 182,
#               'dilutes': 183,
#               'potency': 184,
#               'otherwise': 185,
#               'respectable': 186,
#               'flick': 187,
#               'host': 188,
#               'some': 189,
#               'truly': 190,
#               'excellent': 191,
#               'sequences': 192,
#               'australian': 193,
#               'actor\\/director': 194,
#               'john': 195,
#               'polson': 196,
#               'award-winning': 197,
#               'english': 198,
#               'cinematographer': 199,
#               'giles': 200,
#               'nuttgens': 201,
#               'terrific': 202,
#               'effort': 203,
#               'disguising': 204,
#               'energy': 205,
#               'innovation': 206,
#               'walk': 207,
#               'out': 208,
#               'girl': 209,
#               'mixed': 210,
#               'emotions': 211,
#               'disapproval': 212,
#               'justine': 213,
#               'combined': 214,
#               'tinge': 215,
#               'understanding': 216,
#               'her': 217,
#               'actions': 218,
#               'post': 219,
#               '9\\/11': 220,
#               'philosophical': 221,
#               'message': 222,
#               'personal': 223,
#               'freedom': 224,
#               'might': 225,
#               'as': 226,
#               'palatable': 227,
#               'absorbing': 228,
#               'character': 229,
#               'study': 230,
#               'andrã©': 231,
#               'turpin': 232,
#               'if': 233,
#               'love': 234,
#               'reading': 235,
#               'and\\/or': 236,
#               'poetry': 237,
#               'then': 238,
#               'all': 239,
#               'means': 240,
#               'check': 241,
#               "'ll": 242,
#               'probably': 243,
#               'frailty': 244,
#               'has': 245,
#               'been': 246,
#               'written': 247,
#               'well': 248,
#               'simple': 249,
#               'goddammit': 250,
#               '!': 251,
#               'near': 252,
#               'end': 253,
#               'takes': 254,
#               'meaning': 255,
#               'grenier': 256,
#               'bringing': 257,
#               'unforced': 258,
#               'rapid-fire': 259,
#               'delivery': 260,
#               'toback': 261,
#               'heidegger': 262,
#               '-': 263,
#               'nietzsche-referencing': 264,
#               'sundance': 265,
#               'film': 266,
#               'festival': 267,
#               'become': 268,
#               'buzz-obsessed': 269,
#               'fans': 270,
#               'producers': 271,
#               'descend': 272,
#               'upon': 273,
#               'utah': 274,
#               'each': 275,
#               'january': 276,
#               'ferret': 277,
#               'next': 278,
#               'great': 279,
#               'thing': 280,
#               '`': 281,
#               'tadpole': 282,
#               "'": 283,
#               'was': 284,
#               'one': 285,
#               'films': 286,
#               'declared': 287,
#               'year': 288,
#               'really': 289,
#               'pretty': 290,
#               'actors': 291,
#               'fantastic': 292,
#               'they': 293,
#               'what': 294,
#               'makes': 295,
#               'worth': 296,
#               'trip': 297,
#               'theatre': 298,
#               '-lrb-': 299,
#               'taymor': 300,
#               '-rrb-': 301,
#               'utilizes': 302,
#               'idea': 303,
#               'making': 304,
#               'kahlo': 305,
#               'art': 306,
#               'living': 307,
#               'breathing': 308,
#               'movie': 309,
#               'often': 310,
#               'catapulting': 311,
#               'artist': 312,
#               'into': 313,
#               'own': 314,
#               'work': 315,
#               "n't": 316,
#               'done': 317,
#               'before': 318,
#               'never': 319,
#               'vividly': 320,
#               'much': 321,
#               'passion': 322,
#               'take': 323,
#               'care': 324,
#               'my': 325,
#               'cat': 326,
#               'honestly': 327,
#               'nice': 328,
#               'little': 329,
#               'us': 330,
#               'examination': 331,
#               'young': 332,
#               'adult': 333,
#               'life': 334,
#               'urban': 335,
#               'south': 336,
#               'korea': 337,
#               'through': 338,
#               'minds': 339,
#               'five': 340,
#               'principals': 341,
#               'life-affirming': 342,
#               'its': 343,
#               'vulgar': 344,
#               'mean': 345,
#               'i': 346,
#               'liked': 347,
#               'empire': 348,
#               'lacks': 349,
#               'depth': 350,
#               'up': 351,
#               'heart': 352,
#               'silly': 353,
#               'photographed': 354,
#               'colour': 355,
#               'rather': 356,
#               'time': 357,
#               'tongue-in-cheek': 358,
#               'preposterousness': 359,
#               'always': 360,
#               'most': 361,
#               'wilde': 362,
#               'droll': 363,
#               'whimsy': 364,
#               'helps': 365,
#               'being': 366,
#               'earnest': 367,
#               'overcome': 368,
#               'weaknesses': 369,
#               'parker': 370,
#               'creative': 371,
#               'interference': 372,
#               '...': 373,
#               'lies': 374,
#               'utter': 375,
#               'cuteness': 376,
#               'stuart': 377,
#               'margolo': 378,
#               'computer-animated': 379,
#               'faces': 380,
#               'very': 381,
#               'expressive': 382,
#               'path': 383,
#               'ice': 384,
#               'age': 385,
#               'follows': 386,
#               'closely': 387,
#               'though': 388,
#               'established': 389,
#               'warner': 390,
#               'bros.': 391,
#               'giant': 392,
#               'chuck': 393,
#               'jones': 394,
#               'who': 395,
#               'died': 396,
#               'matter': 397,
#               'weeks': 398,
#               'release': 399,
#               'spiced': 400,
#               'humor': 401,
#               'speak': 402,
#               'fluent': 403,
#               'flatula': 404,
#               'advises': 405,
#               'denlopp': 406,
#               'after': 407,
#               'bubbly': 408,
#               'exchange': 409,
#               'alien': 410,
#               'deckhand': 411,
#               'witty': 412,
#               'updatings': 413,
#               'silver': 414,
#               'parrot': 415,
#               'replaced': 416,
#               'morph': 417,
#               'cute': 418,
#               'creature': 419,
#               'mimics': 420,
#               'everyone': 421,
#               'everything': 422,
#               'around': 423,
#               'there': 424,
#               'y': 425,
#               'tu': 426,
#               'mamã¡': 427,
#               'tambiã©n': 428,
#               'comes': 429,
#               'from': 430,
#               'brave': 431,
#               'uninhibited': 432,
#               'performances': 433,
#               'lead': 434,
#               '13': 435,
#               'conversations': 436,
#               'holds': 437,
#               'goodwill': 438,
#               'close': 439,
#               'relatively': 440,
#               'slow': 441,
#               'come': 442,
#               'point': 443,
#               'auto': 444,
#               'focus': 445,
#               'works': 446,
#               'unusual': 447,
#               'biopic': 448,
#               'document': 449,
#               'male': 450,
#               'swingers': 451,
#               'playboy': 452,
#               'era': 453,
#               'mr.': 454,
#               'zhang': 455,
#               'subject': 456,
#               'degree': 457,
#               'least': 458,
#               'quintessentially': 459,
#               'american': 460,
#               'his': 461,
#               'approach': 462,
#               'storytelling': 463,
#               'called': 464,
#               'iranian': 465,
#               'sour': 466,
#               'core': 467,
#               'exploration': 468,
#               'emptiness': 469,
#               'underlay': 470,
#               'relentless': 471,
#               'gaiety': 472,
#               '1920': 473,
#               'ending': 474,
#               '?': 475,
#               'feeling': 476,
#               'deal': 477,
#               'cremaster': 478,
#               '3': 479,
#               'warning': 480,
#               'serious': 481,
#               'buffs': 482,
#               'only': 483,
#               'made': 484,
#               'me': 485,
#               'unintentionally': 486,
#               'famous': 487,
#               'queasy-stomached': 488,
#               'critic': 489,
#               'staggered': 490,
#               'theater': 491,
#               'blacked': 492,
#               'lobby': 493,
#               'believe': 494,
#               'beautiful': 495,
#               'evocative': 496,
#               "'ve": 497,
#               'seen': 498,
#               'garcã\xada': 499,
#               'bernal': 500,
#               'talancã³n': 501,
#               'immensely': 502,
#               'appealing': 503,
#               'couple': 504,
#               'predictable': 505,
#               'want': 506,
#               'things': 507,
#               'spoof': 508,
#               'comedy': 509,
#               'carries': 510,
#               'share': 511,
#               'laughs': 512,
#               'sometimes': 513,
#               'chuckle': 514,
#               'guffaw': 515,
#               'pleasure': 516,
#               'occasional': 517,
#               'belly': 518,
#               'laugh': 519,
#               'city': 520,
#               'reminds': 521,
#               'how': 522,
#               'realistically': 523,
#               'nuanced': 524,
#               'robert': 525,
#               'de': 526,
#               'niro': 527,
#               'performance': 528,
#               'when': 529,
#               'lucratively': 530,
#               'engaged': 531,
#               'shameless': 532,
#               'self-caricature': 533,
#               'analyze': 534,
#               '1999': 535,
#               'promised': 536,
#               'threatened': 537,
#               'later': 538,
#               'wanton': 539,
#               'slipperiness': 540,
#               '\\*': 541,
#               'corpus': 542,
#               'amiable': 543,
#               'jerking': 544,
#               'reshaping': 545,
#               'physical': 546,
#               'space': 547,
#               'watch': 548,
#               'kids': 549,
#               'use': 550,
#               'introduce': 551,
#               'video': 552,
#               'starts': 553,
#               'typical': 554,
#               'bible': 555,
#               'killer': 556,
#               'turns': 557,
#               'significantly': 558,
#               'different': 559,
#               'better': 560,
#               'theme': 561,
#               'those': 562,
#               'pride': 563,
#               'themselves': 564,
#               'sophisticated': 565,
#               'discerning': 566,
#               'taste': 567,
#               'seem': 568,
#               'proper': 569,
#               'cup': 570,
#               'tea': 571,
#               'however': 572,
#               'almost': 573,
#               'guaranteed': 574,
#               'stuffiest': 575,
#               'cinema': 576,
#               'goers': 577,
#               'will': 578,
#               '\\*\\*\\*': 579,
#               'off': 580,
#               'hour-and-a-half': 581,
#               'cuts': 582,
#               'actually': 583,
#               'face': 584,
#               'your': 585,
#               'fears': 586,
#               'world': 587,
#               'boys': 588,
#               'boy': 589,
#               'big': 590,
#               'metaphorical': 591,
#               'wave': 592,
#               'wherever': 593,
#               'welcome': 594,
#               'relief': 595,
#               'baseball': 596,
#               'movies': 597,
#               'try': 598,
#               'too': 599,
#               'hard': 600,
#               'mythic': 601,
#               'sweet': 602,
#               'modest': 603,
#               'ultimately': 604,
#               'winning': 605,
#               'crisp': 606,
#               'psychological': 607,
#               'drama': 608,
#               'thriller': 609,
#               'perfect': 610,
#               'old': 611,
#               'twilight': 612,
#               'zone': 613,
#               'episode': 614,
#               'moments': 615,
#               'insightful': 616,
#               'fondly': 617,
#               'remembered': 618,
#               'endlessly': 619,
#               'challenging': 620,
#               'maze': 621,
#               'moviegoing': 622,
#               'opening': 623,
#               'contrived': 624,
#               'banter': 625,
#               'cliches': 626,
#               'loose': 627,
#               'ends': 628,
#               'second': 629,
#               'half': 630,
#               'uncluttered': 631,
#               'resonant': 632,
#               'gem': 633,
#               'relays': 634,
#               'universal': 635,
#               'points': 636,
#               'without': 637,
#               'confrontations': 638,
#               'cockettes': 639,
#               'provides': 640,
#               'window': 641,
#               'subculture': 642,
#               'hell-bent': 643,
#               'expressing': 644,
#               'itself': 645,
#               'every': 646,
#               'way': 647,
#               'imaginable': 648,
#               'smart': 649,
#               'steamy': 650,
#               'mix': 651,
#               'road': 652,
#               'coming-of-age': 653,
#               'political': 654,
#               'satire': 655,
#               'modern-day': 656,
#               'royals': 657,
#               'nothing': 658,
#               'these': 659,
#               'guys': 660,
#               'scandals': 661,
#               'fairy': 662,
#               'tales': 663,
#               'princesses': 664,
#               'married': 665,
#               'reason': 666,
#               'live': 667,
#               'happily': 668,
#               'ever': 669,
#               'b': 670,
#               'fact': 671,
#               'best': 672,
#               'recent': 673,
#               'memory': 674,
#               'birthday': 675,
#               'actor': 676,
#               'foremost': 677,
#               'walked': 678,
#               'away': 679,
#               'version': 680,
#               'e.t.': 681,
#               'hoped': 682,
#               'moist': 683,
#               'eyes': 684,
#               'devotees': 685,
#               'french': 686,
#               'safe': 687,
#               'conduct': 688,
#               'rich': 689,
#               'period': 690,
#               'minutiae': 691,
#               'dying': 692,
#               'celluloid': 693,
#               'heaven': 694,
#               'characters': 695,
#               'resemblance': 696,
#               'everyday': 697,
#               'children': 698,
#               'shamelessly': 699,
#               'resorting': 700,
#               'pee-related': 701,
#               'sight': 702,
#               'gags': 703,
#               'cause': 704,
#               'tom': 705,
#               'green': 706,
#               'grimace': 707,
#               'myer': 708,
#               'silliness': 709,
#               'eventually': 710,
#               'prevail': 711,
#               'absurdist': 712,
#               'spider': 713,
#               'web': 714,
#               'happy': 715,
#               'listening': 716,
#               'watching': 717,
#               'them': 718,
#               'parade': 719,
#               'fascinates': 720,
#               'right': 721,
#               'moves': 722,
#               'beyond': 723,
#               'original': 724,
#               'nostalgia': 725,
#               'communal': 726,
#               'experiences': 727,
#               'yesteryear': 728,
#               'deeper': 729,
#               'realization': 730,
#               'inability': 731,
#               'stand': 732,
#               'true': 733,
#               'lived': 734,
#               'experience': 735,
#               'blend': 736,
#               'together': 737,
#               'distant': 738,
#               'memories': 739,
#               'mention': 740,
#               'solaris': 741,
#               'years': 742,
#               "'m": 743,
#               'sure': 744,
#               'saw': 745,
#               'opinion': 746,
#               'allen': 747,
#               'funniest': 748,
#               'likeable': 749,
#               'glorious': 750,
#               'spectacle': 751,
#               'd.w.': 752,
#               'griffith': 753,
#               'early': 754,
#               'days': 755,
#               'silent': 756,
#               'comic': 757,
#               'delightful': 758,
#               'derivative': 759,
#               'timely': 760,
#               'director': 761,
#               'could': 762,
#               'dreamed': 763,
#               'quietly': 764,
#               'lyrical': 765,
#               'tale': 766,
#               'probes': 767,
#               'ambiguous': 768,
#               'extended': 769,
#               'iran': 770,
#               'afghani': 771,
#               'streamed': 772,
#               'across': 773,
#               'borders': 774,
#               'desperate': 775,
#               'food': 776,
#               'leaping': 777,
#               'line': 778,
#               'shaped': 779,
#               'kosminsky': 780,
#               'sharp': 781,
#               'slivers': 782,
#               'cutting': 783,
#               'impressions': 784,
#               'shows': 785,
#               'signs': 786,
#               'detail': 787,
#               'condensed': 788,
#               'images': 789,
#               'striking': 790,
#               'traits': 791,
#               'three': 792,
#               'principal': 793,
#               'singers': 794,
#               'youthful': 795,
#               'good-looking': 796,
#               'diva': 797,
#               'tenor': 798,
#               'richly': 799,
#               'handsome': 800,
#               'locations': 801,
#               'wish': 802,
#               'jacquot': 803,
#               'left': 804,
#               'alone': 805,
#               'filmed': 806,
#               'opera': 807,
#               'distortions': 808,
#               'perspective': 809,
#               'production': 810,
#               'enormous': 811,
#               'amount': 812,
#               'affection': 813,
#               'we': 814,
#               'worthwhile': 815,
#               'winds': 816,
#               'both': 817,
#               'revelatory': 818,
#               'narcissistic': 819,
#               'achieving': 820,
#               'honest': 821,
#               'insight': 822,
#               'relationships': 823,
#               'high-concept': 824,
#               'candy-coat': 825,
#               'pat': 826,
#               'storylines': 827,
#               'precious': 828,
#               'circumstances': 829,
#               'stars': 830,
#               'inspiring': 831,
#               'joy': 832,
#               'spielberg': 833,
#               'brings': 834,
#               'another': 835,
#               'masterpiece': 836,
#               'finally': 837,
#               'french-produced': 838,
#               'read': 839,
#               'lips': 840,
#               'understands': 841,
#               'must': 842,
#               'ms.': 843,
#               'seigner': 844,
#               'serrault': 845,
#               'bring': 846,
#               'fresh': 847,
#               'naturalism': 848,
#               'outgag': 849,
#               'whippersnappers': 850,
#               'moving': 851,
#               'pictures': 852,
#               'today': 853,
#               'solid': 854,
#               'pedigree': 855,
#               'front': 856,
#               'specifically': 857,
#               'behind': 858,
#               'camera': 859,
#               'no': 860,
#               'slam-dunk': 861,
#               'disappoint': 862,
#               'moved': 863,
#               'edge': 864,
#               'seats': 865,
#               'dynamic': 866,
#               'touching': 867,
#               'transcendent': 868,
#               'encourage': 869,
#               'alike': 870,
#               'go': 871,
#               'see': 872,
#               'unique': 873,
#               'entertaining': 874,
#               'twist': 875,
#               'classic': 876,
#               'whale': 877,
#               'wo': 878,
#               'sorry': 879,
#               'literary': 880,
#               'detective': 881,
#               'aficionados': 882,
#               'whodunit': 883,
#               'disappointed': 884,
#               'high': 885,
#               'crimes': 886,
#               'steals': 887,
#               'freely': 888,
#               'combines': 889,
#               'disparate': 890,
#               'types': 891,
#               'ca': 892,
#               'help': 893,
#               'engage': 894,
#               'audience': 895,
#               'fan': 896,
#               'series': 897,
#               'twice': 898,
#               'celebrates': 899,
#               'group': 900,
#               'spark': 901,
#               'nonconformity': 902,
#               'glancing': 903,
#               'back': 904,
#               'hibiscus': 905,
#               'grandly': 906,
#               'angels': 907,
#               'ironic': 908,
#               'ridiculous': 909,
#               'money-oriented': 910,
#               'record': 911,
#               'industry': 912,
#               'also': 913,
#               'testament': 914,
#               'integrity': 915,
#               'band': 916,
#               'laced': 917,
#               'liberal': 918,
#               'doses': 919,
#               'dark': 920,
#               'gorgeous': 921,
#               'exterior': 922,
#               'photography': 923,
#               'stable-full': 924,
#               'such': 925,
#               'huppert': 926,
#               'show': 927,
#               'steal': 928,
#               'she': 929,
#               'meal': 930,
#               'channeling': 931,
#               'kathy': 932,
#               'baker': 933,
#               'creepy': 934,
#               'turn': 935,
#               'repressed': 936,
#               'mother': 937,
#               'boston': 938,
#               'public': 939,
#               '8': 940,
#               'women': 941,
#               'augustine': 942,
#               'nair': 943,
#               'does': 944,
#               'treat': 945,
#               'issues': 946,
#               'lightly': 947,
#               'allows': 948,
#               'confront': 949,
#               'problems': 950,
#               'openly': 951,
#               'horror': 952,
#               'real': 953,
#               'shocks': 954,
#               'store': 955,
#               'unwary': 956,
#               'viewers': 957,
#               'filmmaker': 958,
#               'secrets': 959,
#               'buried': 960,
#               'knows': 961,
#               'revealing': 962,
#               'strange': 963,
#               'occurrences': 964,
#               'build': 965,
#               'mind': 966,
#               'viewer': 967,
#               'urgency': 968,
#               'certain': 969,
#               'ghoulish': 970,
#               'fascination': 971,
#               'generates': 972,
#               'fair': 973,
#               'b-movie': 974,
#               'excitement': 975,
#               'familiar': 976,
#               'utterly': 977,
#               'keeps': 978,
#               'hooked': 979,
#               'delicious': 980,
#               'pulpiness': 981,
#               'lurid': 982,
#               'fiction': 983,
#               'aims': 984,
#               'funny': 985,
#               'uplifting': 986,
#               'once': 987,
#               'extent': 988,
#               'which': 989,
#               'succeeds': 990,
#               'impressive': 991,
#               'brilliantly': 992,
#               'shines': 993,
#               'direction': 994,
#               'intelligently': 995,
#               'accomplished': 996,
#               'while': 997,
#               'collegiate': 998,
#               'gross-out': 999,
#               ...}))

# %%
t2i # tags to indices
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'3': 0, '4': 1, '2': 2, '1': 3, '0': 4})

# %%
i2w = {v:k for k,v in w2i.items()}
i2w[0] = "<unk>"
i2w
# Out:
# {0: '<unk>',
#  1: 'the',
#  2: 'rock',
#  3: 'is',
#  4: 'destined',
#  5: 'to',
#  6: 'be',
#  7: '21st',
#  8: 'century',
#  9: "'s",
#  10: 'new',
#  11: '``',
#  12: 'conan',
#  13: "''",
#  14: 'and',
#  15: 'that',
#  16: 'he',
#  17: 'going',
#  18: 'make',
#  19: 'a',
#  20: 'splash',
#  21: 'even',
#  22: 'greater',
#  23: 'than',
#  24: 'arnold',
#  25: 'schwarzenegger',
#  26: ',',
#  27: 'jean-claud',
#  28: 'van',
#  29: 'damme',
#  30: 'or',
#  31: 'steven',
#  32: 'segal',
#  33: '.',
#  34: 'gorgeously',
#  35: 'elaborate',
#  36: 'continuation',
#  37: 'of',
#  38: 'lord',
#  39: 'rings',
#  40: 'trilogy',
#  41: 'so',
#  42: 'huge',
#  43: 'column',
#  44: 'words',
#  45: 'can',
#  46: 'not',
#  47: 'adequately',
#  48: 'describe',
#  49: 'co-writer\\/director',
#  50: 'peter',
#  51: 'jackson',
#  52: 'expanded',
#  53: 'vision',
#  54: 'j.r.r.',
#  55: 'tolkien',
#  56: 'middle-earth',
#  57: 'singer\\/composer',
#  58: 'bryan',
#  59: 'adams',
#  60: 'contributes',
#  61: 'slew',
#  62: 'songs',
#  63: '--',
#  64: 'few',
#  65: 'potential',
#  66: 'hits',
#  67: 'more',
#  68: 'simply',
#  69: 'intrusive',
#  70: 'story',
#  71: 'but',
#  72: 'whole',
#  73: 'package',
#  74: 'certainly',
#  75: 'captures',
#  76: 'intended',
#  77: 'er',
#  78: 'spirit',
#  79: 'piece',
#  80: 'you',
#  81: "'d",
#  82: 'think',
#  83: 'by',
#  84: 'now',
#  85: 'america',
#  86: 'would',
#  87: 'have',
#  88: 'had',
#  89: 'enough',
#  90: 'plucky',
#  91: 'british',
#  92: 'eccentrics',
#  93: 'with',
#  94: 'hearts',
#  95: 'gold',
#  96: 'yet',
#  97: 'act',
#  98: 'still',
#  99: 'charming',
#  100: 'here',
#  101: 'whether',
#  102: "'re",
#  103: 'enlightened',
#  104: 'any',
#  105: 'derrida',
#  106: 'lectures',
#  107: 'on',
#  108: 'other',
#  109: 'self',
#  110: 'an',
#  111: 'undeniably',
#  112: 'fascinating',
#  113: 'playful',
#  114: 'fellow',
#  115: 'just',
#  116: 'labour',
#  117: 'involved',
#  118: 'in',
#  119: 'creating',
#  120: 'layered',
#  121: 'richness',
#  122: 'imagery',
#  123: 'this',
#  124: 'chiaroscuro',
#  125: 'madness',
#  126: 'light',
#  127: 'astonishing',
#  128: 'part',
#  129: 'charm',
#  130: 'satin',
#  131: 'rouge',
#  132: 'it',
#  133: 'avoids',
#  134: 'obvious',
#  135: 'humour',
#  136: 'lightness',
#  137: 'screenplay',
#  138: 'ingeniously',
#  139: 'constructed',
#  140: 'memento',
#  141: 'extreme',
#  142: 'ops',
#  143: 'exceeds',
#  144: 'expectations',
#  145: 'good',
#  146: 'fun',
#  147: 'action',
#  148: 'acting',
#  149: 'dialogue',
#  150: 'pace',
#  151: 'cinematography',
#  152: 'should',
#  153: 'pay',
#  154: 'nine',
#  155: 'bucks',
#  156: 'for',
#  157: ':',
#  158: 'because',
#  159: 'hear',
#  160: 'about',
#  161: 'suffering',
#  162: 'afghan',
#  163: 'refugees',
#  164: 'news',
#  165: 'unaffected',
#  166: 'dramas',
#  167: 'like',
#  168: 'human',
#  169: 'thunderous',
#  170: 'ride',
#  171: 'at',
#  172: 'first',
#  173: 'quiet',
#  174: 'cadences',
#  175: 'pure',
#  176: 'finesse',
#  177: 'are',
#  178: 'far',
#  179: 'between',
#  180: ';',
#  181: 'their',
#  182: 'shortage',
#  183: 'dilutes',
#  184: 'potency',
#  185: 'otherwise',
#  186: 'respectable',
#  187: 'flick',
#  188: 'host',
#  189: 'some',
#  190: 'truly',
#  191: 'excellent',
#  192: 'sequences',
#  193: 'australian',
#  194: 'actor\\/director',
#  195: 'john',
#  196: 'polson',
#  197: 'award-winning',
#  198: 'english',
#  199: 'cinematographer',
#  200: 'giles',
#  201: 'nuttgens',
#  202: 'terrific',
#  203: 'effort',
#  204: 'disguising',
#  205: 'energy',
#  206: 'innovation',
#  207: 'walk',
#  208: 'out',
#  209: 'girl',
#  210: 'mixed',
#  211: 'emotions',
#  212: 'disapproval',
#  213: 'justine',
#  214: 'combined',
#  215: 'tinge',
#  216: 'understanding',
#  217: 'her',
#  218: 'actions',
#  219: 'post',
#  220: '9\\/11',
#  221: 'philosophical',
#  222: 'message',
#  223: 'personal',
#  224: 'freedom',
#  225: 'might',
#  226: 'as',
#  227: 'palatable',
#  228: 'absorbing',
#  229: 'character',
#  230: 'study',
#  231: 'andrã©',
#  232: 'turpin',
#  233: 'if',
#  234: 'love',
#  235: 'reading',
#  236: 'and\\/or',
#  237: 'poetry',
#  238: 'then',
#  239: 'all',
#  240: 'means',
#  241: 'check',
#  242: "'ll",
#  243: 'probably',
#  244: 'frailty',
#  245: 'has',
#  246: 'been',
#  247: 'written',
#  248: 'well',
#  249: 'simple',
#  250: 'goddammit',
#  251: '!',
#  252: 'near',
#  253: 'end',
#  254: 'takes',
#  255: 'meaning',
#  256: 'grenier',
#  257: 'bringing',
#  258: 'unforced',
#  259: 'rapid-fire',
#  260: 'delivery',
#  261: 'toback',
#  262: 'heidegger',
#  263: '-',
#  264: 'nietzsche-referencing',
#  265: 'sundance',
#  266: 'film',
#  267: 'festival',
#  268: 'become',
#  269: 'buzz-obsessed',
#  270: 'fans',
#  271: 'producers',
#  272: 'descend',
#  273: 'upon',
#  274: 'utah',
#  275: 'each',
#  276: 'january',
#  277: 'ferret',
#  278: 'next',
#  279: 'great',
#  280: 'thing',
#  281: '`',
#  282: 'tadpole',
#  283: "'",
#  284: 'was',
#  285: 'one',
#  286: 'films',
#  287: 'declared',
#  288: 'year',
#  289: 'really',
#  290: 'pretty',
#  291: 'actors',
#  292: 'fantastic',
#  293: 'they',
#  294: 'what',
#  295: 'makes',
#  296: 'worth',
#  297: 'trip',
#  298: 'theatre',
#  299: '-lrb-',
#  300: 'taymor',
#  301: '-rrb-',
#  302: 'utilizes',
#  303: 'idea',
#  304: 'making',
#  305: 'kahlo',
#  306: 'art',
#  307: 'living',
#  308: 'breathing',
#  309: 'movie',
#  310: 'often',
#  311: 'catapulting',
#  312: 'artist',
#  313: 'into',
#  314: 'own',
#  315: 'work',
#  316: "n't",
#  317: 'done',
#  318: 'before',
#  319: 'never',
#  320: 'vividly',
#  321: 'much',
#  322: 'passion',
#  323: 'take',
#  324: 'care',
#  325: 'my',
#  326: 'cat',
#  327: 'honestly',
#  328: 'nice',
#  329: 'little',
#  330: 'us',
#  331: 'examination',
#  332: 'young',
#  333: 'adult',
#  334: 'life',
#  335: 'urban',
#  336: 'south',
#  337: 'korea',
#  338: 'through',
#  339: 'minds',
#  340: 'five',
#  341: 'principals',
#  342: 'life-affirming',
#  343: 'its',
#  344: 'vulgar',
#  345: 'mean',
#  346: 'i',
#  347: 'liked',
#  348: 'empire',
#  349: 'lacks',
#  350: 'depth',
#  351: 'up',
#  352: 'heart',
#  353: 'silly',
#  354: 'photographed',
#  355: 'colour',
#  356: 'rather',
#  357: 'time',
#  358: 'tongue-in-cheek',
#  359: 'preposterousness',
#  360: 'always',
#  361: 'most',
#  362: 'wilde',
#  363: 'droll',
#  364: 'whimsy',
#  365: 'helps',
#  366: 'being',
#  367: 'earnest',
#  368: 'overcome',
#  369: 'weaknesses',
#  370: 'parker',
#  371: 'creative',
#  372: 'interference',
#  373: '...',
#  374: 'lies',
#  375: 'utter',
#  376: 'cuteness',
#  377: 'stuart',
#  378: 'margolo',
#  379: 'computer-animated',
#  380: 'faces',
#  381: 'very',
#  382: 'expressive',
#  383: 'path',
#  384: 'ice',
#  385: 'age',
#  386: 'follows',
#  387: 'closely',
#  388: 'though',
#  389: 'established',
#  390: 'warner',
#  391: 'bros.',
#  392: 'giant',
#  393: 'chuck',
#  394: 'jones',
#  395: 'who',
#  396: 'died',
#  397: 'matter',
#  398: 'weeks',
#  399: 'release',
#  400: 'spiced',
#  401: 'humor',
#  402: 'speak',
#  403: 'fluent',
#  404: 'flatula',
#  405: 'advises',
#  406: 'denlopp',
#  407: 'after',
#  408: 'bubbly',
#  409: 'exchange',
#  410: 'alien',
#  411: 'deckhand',
#  412: 'witty',
#  413: 'updatings',
#  414: 'silver',
#  415: 'parrot',
#  416: 'replaced',
#  417: 'morph',
#  418: 'cute',
#  419: 'creature',
#  420: 'mimics',
#  421: 'everyone',
#  422: 'everything',
#  423: 'around',
#  424: 'there',
#  425: 'y',
#  426: 'tu',
#  427: 'mamã¡',
#  428: 'tambiã©n',
#  429: 'comes',
#  430: 'from',
#  431: 'brave',
#  432: 'uninhibited',
#  433: 'performances',
#  434: 'lead',
#  435: '13',
#  436: 'conversations',
#  437: 'holds',
#  438: 'goodwill',
#  439: 'close',
#  440: 'relatively',
#  441: 'slow',
#  442: 'come',
#  443: 'point',
#  444: 'auto',
#  445: 'focus',
#  446: 'works',
#  447: 'unusual',
#  448: 'biopic',
#  449: 'document',
#  450: 'male',
#  451: 'swingers',
#  452: 'playboy',
#  453: 'era',
#  454: 'mr.',
#  455: 'zhang',
#  456: 'subject',
#  457: 'degree',
#  458: 'least',
#  459: 'quintessentially',
#  460: 'american',
#  461: 'his',
#  462: 'approach',
#  463: 'storytelling',
#  464: 'called',
#  465: 'iranian',
#  466: 'sour',
#  467: 'core',
#  468: 'exploration',
#  469: 'emptiness',
#  470: 'underlay',
#  471: 'relentless',
#  472: 'gaiety',
#  473: '1920',
#  474: 'ending',
#  475: '?',
#  476: 'feeling',
#  477: 'deal',
#  478: 'cremaster',
#  479: '3',
#  480: 'warning',
#  481: 'serious',
#  482: 'buffs',
#  483: 'only',
#  484: 'made',
#  485: 'me',
#  486: 'unintentionally',
#  487: 'famous',
#  488: 'queasy-stomached',
#  489: 'critic',
#  490: 'staggered',
#  491: 'theater',
#  492: 'blacked',
#  493: 'lobby',
#  494: 'believe',
#  495: 'beautiful',
#  496: 'evocative',
#  497: "'ve",
#  498: 'seen',
#  499: 'garcã\xada',
#  500: 'bernal',
#  501: 'talancã³n',
#  502: 'immensely',
#  503: 'appealing',
#  504: 'couple',
#  505: 'predictable',
#  506: 'want',
#  507: 'things',
#  508: 'spoof',
#  509: 'comedy',
#  510: 'carries',
#  511: 'share',
#  512: 'laughs',
#  513: 'sometimes',
#  514: 'chuckle',
#  515: 'guffaw',
#  516: 'pleasure',
#  517: 'occasional',
#  518: 'belly',
#  519: 'laugh',
#  520: 'city',
#  521: 'reminds',
#  522: 'how',
#  523: 'realistically',
#  524: 'nuanced',
#  525: 'robert',
#  526: 'de',
#  527: 'niro',
#  528: 'performance',
#  529: 'when',
#  530: 'lucratively',
#  531: 'engaged',
#  532: 'shameless',
#  533: 'self-caricature',
#  534: 'analyze',
#  535: '1999',
#  536: 'promised',
#  537: 'threatened',
#  538: 'later',
#  539: 'wanton',
#  540: 'slipperiness',
#  541: '\\*',
#  542: 'corpus',
#  543: 'amiable',
#  544: 'jerking',
#  545: 'reshaping',
#  546: 'physical',
#  547: 'space',
#  548: 'watch',
#  549: 'kids',
#  550: 'use',
#  551: 'introduce',
#  552: 'video',
#  553: 'starts',
#  554: 'typical',
#  555: 'bible',
#  556: 'killer',
#  557: 'turns',
#  558: 'significantly',
#  559: 'different',
#  560: 'better',
#  561: 'theme',
#  562: 'those',
#  563: 'pride',
#  564: 'themselves',
#  565: 'sophisticated',
#  566: 'discerning',
#  567: 'taste',
#  568: 'seem',
#  569: 'proper',
#  570: 'cup',
#  571: 'tea',
#  572: 'however',
#  573: 'almost',
#  574: 'guaranteed',
#  575: 'stuffiest',
#  576: 'cinema',
#  577: 'goers',
#  578: 'will',
#  579: '\\*\\*\\*',
#  580: 'off',
#  581: 'hour-and-a-half',
#  582: 'cuts',
#  583: 'actually',
#  584: 'face',
#  585: 'your',
#  586: 'fears',
#  587: 'world',
#  588: 'boys',
#  589: 'boy',
#  590: 'big',
#  591: 'metaphorical',
#  592: 'wave',
#  593: 'wherever',
#  594: 'welcome',
#  595: 'relief',
#  596: 'baseball',
#  597: 'movies',
#  598: 'try',
#  599: 'too',
#  600: 'hard',
#  601: 'mythic',
#  602: 'sweet',
#  603: 'modest',
#  604: 'ultimately',
#  605: 'winning',
#  606: 'crisp',
#  607: 'psychological',
#  608: 'drama',
#  609: 'thriller',
#  610: 'perfect',
#  611: 'old',
#  612: 'twilight',
#  613: 'zone',
#  614: 'episode',
#  615: 'moments',
#  616: 'insightful',
#  617: 'fondly',
#  618: 'remembered',
#  619: 'endlessly',
#  620: 'challenging',
#  621: 'maze',
#  622: 'moviegoing',
#  623: 'opening',
#  624: 'contrived',
#  625: 'banter',
#  626: 'cliches',
#  627: 'loose',
#  628: 'ends',
#  629: 'second',
#  630: 'half',
#  631: 'uncluttered',
#  632: 'resonant',
#  633: 'gem',
#  634: 'relays',
#  635: 'universal',
#  636: 'points',
#  637: 'without',
#  638: 'confrontations',
#  639: 'cockettes',
#  640: 'provides',
#  641: 'window',
#  642: 'subculture',
#  643: 'hell-bent',
#  644: 'expressing',
#  645: 'itself',
#  646: 'every',
#  647: 'way',
#  648: 'imaginable',
#  649: 'smart',
#  650: 'steamy',
#  651: 'mix',
#  652: 'road',
#  653: 'coming-of-age',
#  654: 'political',
#  655: 'satire',
#  656: 'modern-day',
#  657: 'royals',
#  658: 'nothing',
#  659: 'these',
#  660: 'guys',
#  661: 'scandals',
#  662: 'fairy',
#  663: 'tales',
#  664: 'princesses',
#  665: 'married',
#  666: 'reason',
#  667: 'live',
#  668: 'happily',
#  669: 'ever',
#  670: 'b',
#  671: 'fact',
#  672: 'best',
#  673: 'recent',
#  674: 'memory',
#  675: 'birthday',
#  676: 'actor',
#  677: 'foremost',
#  678: 'walked',
#  679: 'away',
#  680: 'version',
#  681: 'e.t.',
#  682: 'hoped',
#  683: 'moist',
#  684: 'eyes',
#  685: 'devotees',
#  686: 'french',
#  687: 'safe',
#  688: 'conduct',
#  689: 'rich',
#  690: 'period',
#  691: 'minutiae',
#  692: 'dying',
#  693: 'celluloid',
#  694: 'heaven',
#  695: 'characters',
#  696: 'resemblance',
#  697: 'everyday',
#  698: 'children',
#  699: 'shamelessly',
#  700: 'resorting',
#  701: 'pee-related',
#  702: 'sight',
#  703: 'gags',
#  704: 'cause',
#  705: 'tom',
#  706: 'green',
#  707: 'grimace',
#  708: 'myer',
#  709: 'silliness',
#  710: 'eventually',
#  711: 'prevail',
#  712: 'absurdist',
#  713: 'spider',
#  714: 'web',
#  715: 'happy',
#  716: 'listening',
#  717: 'watching',
#  718: 'them',
#  719: 'parade',
#  720: 'fascinates',
#  721: 'right',
#  722: 'moves',
#  723: 'beyond',
#  724: 'original',
#  725: 'nostalgia',
#  726: 'communal',
#  727: 'experiences',
#  728: 'yesteryear',
#  729: 'deeper',
#  730: 'realization',
#  731: 'inability',
#  732: 'stand',
#  733: 'true',
#  734: 'lived',
#  735: 'experience',
#  736: 'blend',
#  737: 'together',
#  738: 'distant',
#  739: 'memories',
#  740: 'mention',
#  741: 'solaris',
#  742: 'years',
#  743: "'m",
#  744: 'sure',
#  745: 'saw',
#  746: 'opinion',
#  747: 'allen',
#  748: 'funniest',
#  749: 'likeable',
#  750: 'glorious',
#  751: 'spectacle',
#  752: 'd.w.',
#  753: 'griffith',
#  754: 'early',
#  755: 'days',
#  756: 'silent',
#  757: 'comic',
#  758: 'delightful',
#  759: 'derivative',
#  760: 'timely',
#  761: 'director',
#  762: 'could',
#  763: 'dreamed',
#  764: 'quietly',
#  765: 'lyrical',
#  766: 'tale',
#  767: 'probes',
#  768: 'ambiguous',
#  769: 'extended',
#  770: 'iran',
#  771: 'afghani',
#  772: 'streamed',
#  773: 'across',
#  774: 'borders',
#  775: 'desperate',
#  776: 'food',
#  777: 'leaping',
#  778: 'line',
#  779: 'shaped',
#  780: 'kosminsky',
#  781: 'sharp',
#  782: 'slivers',
#  783: 'cutting',
#  784: 'impressions',
#  785: 'shows',
#  786: 'signs',
#  787: 'detail',
#  788: 'condensed',
#  789: 'images',
#  790: 'striking',
#  791: 'traits',
#  792: 'three',
#  793: 'principal',
#  794: 'singers',
#  795: 'youthful',
#  796: 'good-looking',
#  797: 'diva',
#  798: 'tenor',
#  799: 'richly',
#  800: 'handsome',
#  801: 'locations',
#  802: 'wish',
#  803: 'jacquot',
#  804: 'left',
#  805: 'alone',
#  806: 'filmed',
#  807: 'opera',
#  808: 'distortions',
#  809: 'perspective',
#  810: 'production',
#  811: 'enormous',
#  812: 'amount',
#  813: 'affection',
#  814: 'we',
#  815: 'worthwhile',
#  816: 'winds',
#  817: 'both',
#  818: 'revelatory',
#  819: 'narcissistic',
#  820: 'achieving',
#  821: 'honest',
#  822: 'insight',
#  823: 'relationships',
#  824: 'high-concept',
#  825: 'candy-coat',
#  826: 'pat',
#  827: 'storylines',
#  828: 'precious',
#  829: 'circumstances',
#  830: 'stars',
#  831: 'inspiring',
#  832: 'joy',
#  833: 'spielberg',
#  834: 'brings',
#  835: 'another',
#  836: 'masterpiece',
#  837: 'finally',
#  838: 'french-produced',
#  839: 'read',
#  840: 'lips',
#  841: 'understands',
#  842: 'must',
#  843: 'ms.',
#  844: 'seigner',
#  845: 'serrault',
#  846: 'bring',
#  847: 'fresh',
#  848: 'naturalism',
#  849: 'outgag',
#  850: 'whippersnappers',
#  851: 'moving',
#  852: 'pictures',
#  853: 'today',
#  854: 'solid',
#  855: 'pedigree',
#  856: 'front',
#  857: 'specifically',
#  858: 'behind',
#  859: 'camera',
#  860: 'no',
#  861: 'slam-dunk',
#  862: 'disappoint',
#  863: 'moved',
#  864: 'edge',
#  865: 'seats',
#  866: 'dynamic',
#  867: 'touching',
#  868: 'transcendent',
#  869: 'encourage',
#  870: 'alike',
#  871: 'go',
#  872: 'see',
#  873: 'unique',
#  874: 'entertaining',
#  875: 'twist',
#  876: 'classic',
#  877: 'whale',
#  878: 'wo',
#  879: 'sorry',
#  880: 'literary',
#  881: 'detective',
#  882: 'aficionados',
#  883: 'whodunit',
#  884: 'disappointed',
#  885: 'high',
#  886: 'crimes',
#  887: 'steals',
#  888: 'freely',
#  889: 'combines',
#  890: 'disparate',
#  891: 'types',
#  892: 'ca',
#  893: 'help',
#  894: 'engage',
#  895: 'audience',
#  896: 'fan',
#  897: 'series',
#  898: 'twice',
#  899: 'celebrates',
#  900: 'group',
#  901: 'spark',
#  902: 'nonconformity',
#  903: 'glancing',
#  904: 'back',
#  905: 'hibiscus',
#  906: 'grandly',
#  907: 'angels',
#  908: 'ironic',
#  909: 'ridiculous',
#  910: 'money-oriented',
#  911: 'record',
#  912: 'industry',
#  913: 'also',
#  914: 'testament',
#  915: 'integrity',
#  916: 'band',
#  917: 'laced',
#  918: 'liberal',
#  919: 'doses',
#  920: 'dark',
#  921: 'gorgeous',
#  922: 'exterior',
#  923: 'photography',
#  924: 'stable-full',
#  925: 'such',
#  926: 'huppert',
#  927: 'show',
#  928: 'steal',
#  929: 'she',
#  930: 'meal',
#  931: 'channeling',
#  932: 'kathy',
#  933: 'baker',
#  934: 'creepy',
#  935: 'turn',
#  936: 'repressed',
#  937: 'mother',
#  938: 'boston',
#  939: 'public',
#  940: '8',
#  941: 'women',
#  942: 'augustine',
#  943: 'nair',
#  944: 'does',
#  945: 'treat',
#  946: 'issues',
#  947: 'lightly',
#  948: 'allows',
#  949: 'confront',
#  950: 'problems',
#  951: 'openly',
#  952: 'horror',
#  953: 'real',
#  954: 'shocks',
#  955: 'store',
#  956: 'unwary',
#  957: 'viewers',
#  958: 'filmmaker',
#  959: 'secrets',
#  960: 'buried',
#  961: 'knows',
#  962: 'revealing',
#  963: 'strange',
#  964: 'occurrences',
#  965: 'build',
#  966: 'mind',
#  967: 'viewer',
#  968: 'urgency',
#  969: 'certain',
#  970: 'ghoulish',
#  971: 'fascination',
#  972: 'generates',
#  973: 'fair',
#  974: 'b-movie',
#  975: 'excitement',
#  976: 'familiar',
#  977: 'utterly',
#  978: 'keeps',
#  979: 'hooked',
#  980: 'delicious',
#  981: 'pulpiness',
#  982: 'lurid',
#  983: 'fiction',
#  984: 'aims',
#  985: 'funny',
#  986: 'uplifting',
#  987: 'once',
#  988: 'extent',
#  989: 'which',
#  990: 'succeeds',
#  991: 'impressive',
#  992: 'brilliantly',
#  993: 'shines',
#  994: 'direction',
#  995: 'intelligently',
#  996: 'accomplished',
#  997: 'while',
#  998: 'collegiate',
#  999: 'gross-out',
#  ...}

# %%
i2t = {v:k for k,v in t2i.items()}
i2t
# Out:
# {0: '3', 1: '4', 2: '2', 3: '1', 4: '0'}

# %%
def decode_sample(sample):
    return [i2w[x] if x in i2w else "<unk>" for x in sample[0]], i2t[sample[1]]

# %%
def get_num_tags(dev):
    zeroes = 0
    ones = 0
    twos = 0
    threes = 0
    fours = 0
    
    for i in range(len(dev)):
        _, tag = decode_sample(dev[i])

        if tag == '0':
            zeroes += 1
        elif tag == '1':
            ones += 1
        elif tag == '2':
            twos += 1
        elif tag =='3':
            threes += 1
        elif tag =='4':
            fours += 1
        
    if (zeroes + ones + twos + threes + fours) != len(dev):
        return 0
    else:
        return zeroes, ones, twos, threes, fours

# %%
def calc_scores(words, W_sm, b_sm):
    dy.renew_cg()
    score = dy.esum([dy.lookup(W_sm, x) for x in words])
    b_sm_exp = dy.parameter(b_sm)
    return score + b_sm_exp

# %%
def correct_and_predicted(dev, W_sm, b_sm):
    correct = []
    predicted = []

    for i in range(len(dev)):
        _, tag = decode_sample(dev[i])

        scores = calc_scores(dev[i][0], W_sm, b_sm).npvalue()
        predict = np.argmax(scores)

        correct.append(tag)
        predicted.append(i2t[predict])

    return correct, predicted

# %% [markdown]
# The distance away calculation works for this classification rating task, but different measures would be needed for other datasets.

# %%
def statistics(correct_list, predicted_list):
    
    absolute_distance = 0
    distance = 0
    total_distance = 0
    
    pos_overattribution = 0
    neg_overattribution = 0
    
    num_correct = 0
    num_wrong_positive = 0
    num_wrong_negative = 0
    
    num_correct = 0
    num_wrong = 0
    
    num_values = len(correct_list)
    
    for i in range(num_values):
        absolute_distance += np.abs(int(predicted_list[i]) - int(correct_list[i]))
        distance = int(predicted_list[i]) - int(correct_list[i])
        total_distance += distance
        
        if distance > 0:
            pos_overattribution += distance
            num_wrong_positive += 1
            num_wrong += 1
        elif distance < 0:
            neg_overattribution += distance
            num_wrong_negative += 1
            num_wrong += 1
        else:
            num_correct += 1
            
    average_absolute_distance = absolute_distance / num_values
    average_distance = total_distance / num_values
    average_wrong_positive = pos_overattribution / num_wrong_positive
    average_wrong_negative = neg_overattribution / num_wrong_negative
    percent_correct = (num_correct / num_values)*100
    percent_wrong = (num_wrong / num_values)*100
    
    print("Average distance away from correct rating across all values, incorrect and correct: ", average_absolute_distance)
    print("Average distance away overall among all predictions: ", average_distance)
    print("When wrong, the model was overly positive by: ", average_wrong_positive)
    print("When wrong, the model was overly negative by: ", average_wrong_negative)
    print("Percent correct: ", percent_correct)
    print("Percent wrong: ", percent_wrong)
    
    return average_absolute_distance, average_distance, average_wrong_positive, average_wrong_negative, percent_correct, percent_wrong

# %%
def mean_of_skew(skewed_data):
    total = 0
    for review in skewed_data:
        total += int(i2t[review[1]])
    return total / len(skewed_data)

# %%
def median_of_skew(skewed_data):
    total = 0
    for review in skewed_data:
        total += int(i2t[review[1]])
    return total / len(skewed_data)

# %%
ends_in_0 = [zero for zero in train_set if i2t[zero[1]] == '0']
ends_in_1 = [one for one in train_set if i2t[one[1]] == '1']
ends_in_2 = [two for two in train_set if i2t[two[1]] == '2']
ends_in_3 = [three for three in train_set if i2t[three[1]] == '3']
ends_in_4 = [four for four in train_set if i2t[four[1]] == '4']

# %%
back_together = ends_in_0 + ends_in_1 + ends_in_2 + ends_in_3 + ends_in_4
len(back_together)
# Out:
# 8544

# %%
ends_in_0_dev = [zero for zero in dev_set if i2t[zero[1]] == '0']
ends_in_1_dev = [one for one in dev_set if i2t[one[1]] == '1']
ends_in_2_dev = [two for two in dev_set if i2t[two[1]] == '2']
ends_in_3_dev = [three for three in dev_set if i2t[three[1]] == '3']
ends_in_4_dev = [four for four in dev_set if i2t[four[1]] == '4']

# %%
back_together_dev = ends_in_0_dev + ends_in_1_dev + ends_in_2_dev + ends_in_3_dev + ends_in_4_dev
len(back_together_dev)
# Out:
# 2210

# %%
words, tag = decode_sample(train_set[10])
" ".join(words), tag
# Out:
# ('good fun , good action , good acting , good dialogue , good pace , good cinematography .',
#  '4')

# %%
get_num_tags(train_set)
# Out:
# (1092, 2218, 1624, 2322, 1288)

# %%
get_num_tags(dev_set)
# Out:
# (279, 633, 389, 510, 399)

# %%
len(ends_in_0), len(ends_in_1), len(ends_in_2), len(ends_in_3), len(ends_in_4)
# Out:
# (1092, 2218, 1624, 2322, 1288)

# %%
len(ends_in_0_dev), len(ends_in_1_dev), len(ends_in_2_dev), len(ends_in_3_dev), len(ends_in_4_dev)
# Out:
# (279, 633, 389, 510, 399)

# %%
def run_train_function(train, dev, learning_rates, num_epochs):
    statistics_per_run = {}

    for num_epoch in num_epochs:
        for learning_rate in learning_rates:
            model = dy.Model()
            trainer = dy.AdamTrainer(model, learning_rate)

            W_sm = model.add_lookup_parameters((nwords, ntags)) # Word weights
            b_sm = model.add_parameters((ntags))                # Softmax bias

            dynet_config.set(random_seed=0)
            dy.renew_cg();


            for ITER in range(num_epoch):
                # Perform training
                random.shuffle(train)
                train_loss = 0.0
                start = time.time()
                for words, tag in train:
                    my_loss = dy.pickneglogsoftmax(calc_scores(words, W_sm, b_sm), tag) # negative softmax log likelihood
                    train_loss += my_loss.value()
                    my_loss.backward()
                    trainer.update()
                if ITER % int(num_epoch/10) == 0:
                    print("iter %r: train loss/sent=%.4f, time=%.2fs" % (ITER, train_loss/len(train), time.time()-start))
                # Perform testing
                test_correct = 0.0
                for words, tag in dev:
                    scores = calc_scores(words, W_sm, b_sm).npvalue()
                    predict = np.argmax(scores)
                    if predict == tag:
                        test_correct += 1
                if ITER % int(num_epoch/10) == 0:
                    print("iter %r: test acc=%.4f" % (ITER, test_correct/len(dev)))

            correct, predicted = correct_and_predicted(dev, W_sm, b_sm)
            average_absolute_distance, average_distance, average_wrong_positive, average_wrong_negative, percent_correct, percent_wrong = statistics(correct, predicted)
            statistics_per_run[(learning_rate, num_epoch)] = (average_absolute_distance, average_distance, average_wrong_positive, average_wrong_negative, percent_correct, percent_wrong)
    
    return statistics_per_run

# %% [markdown]
# best run; .0005 learning rate and 100 epochs

# %%
# learning_rates = [.0001, .0005, .001, .0015]
# num_epochs = [50, 100, 150, 200]

# learning_rates = [.0005, .001]
learning_rates = [.0005]
num_epochs = [100]

# %%
run_train_function(train_set, dev_set, learning_rates, num_epochs)
# Out:
# The dy.parameter(...) call is now DEPRECATED.
#         There is no longer need to explicitly add parameters to the computation graph.
#         Any used parameter will be added automatically.
# iter 0: train loss/sent=1.5327, time=0.31s
# iter 0: test acc=0.3271
# iter 10: train loss/sent=1.0750, time=0.30s
# iter 10: test acc=0.4018
# iter 20: train loss/sent=0.9040, time=0.32s
# iter 20: test acc=0.4104
# iter 30: train loss/sent=0.7984, time=0.30s
# iter 30: test acc=0.4149
# iter 40: train loss/sent=0.7238, time=0.28s
# iter 40: test acc=0.4290
# iter 50: train loss/sent=0.6677, time=0.31s
# iter 50: test acc=0.4122
# iter 60: train loss/sent=0.6227, time=0.27s
# iter 60: test acc=0.4140
# iter 70: train loss/sent=0.5852, time=0.30s
# iter 70: test acc=0.4050
# iter 80: train loss/sent=0.5537, time=0.30s
# iter 80: test acc=0.4104
# iter 90: train loss/sent=0.5261, time=0.30s
# iter 90: test acc=0.4167
# Average distance away from correct rating across all values, incorrect and correct:  0.8257918552036199
# Average distance away overall among all predictions:  0.06380090497737556
# When wrong, the model was overly positive by:  1.4287790697674418
# When wrong, the model was overly negative by:  -1.3472
# Percent correct:  40.588235294117645
# Percent wrong:  59.411764705882355
# {(0.0005, 100): (0.8257918552036199,
#   0.06380090497737556,
#   1.4287790697674418,
#   -1.3472,
#   40.588235294117645,
#   59.411764705882355)}

# %%
baseline = ends_in_0[:1000] + ends_in_1[:1000] + ends_in_2[:1000] + ends_in_3[:1000] + ends_in_4[:1000]

# %%
baseline_dev = ends_in_0_dev[:250] + ends_in_1_dev[:250] + ends_in_2_dev[:250] + ends_in_3_dev[:250] + ends_in_4_dev[:250]

# %%
skew_positive = ends_in_0[:800] + ends_in_1[:850] + ends_in_2[:900] + ends_in_3[:950] + ends_in_4[:1000]
skew_positive2 = ends_in_0[:600] + ends_in_1[:700] + ends_in_2[:800] + ends_in_3[:900] + ends_in_4[:1000]
skew_positive3 = ends_in_0[:400] + ends_in_1[:550] + ends_in_2[:700] + ends_in_3[:850] + ends_in_4[:1000]
skew_positive4 = ends_in_0[:200] + ends_in_1[:400] + ends_in_2[:600] + ends_in_3[:800] + ends_in_4[:1000]
no_0s = ends_in_1[:1000] + ends_in_2[:1000] + ends_in_3[:1000] + ends_in_4[:1000]

skew_negative = ends_in_0[:1000] + ends_in_1[:950] + ends_in_2[:900] + ends_in_3[:850] + ends_in_4[:800]
skew_negative2 = ends_in_0[:1000] + ends_in_1[:900] + ends_in_2[:800] + ends_in_3[:700] + ends_in_4[:600]
skew_negative3 = ends_in_0[:1000] + ends_in_1[:850] + ends_in_2[:700] + ends_in_3[:550] + ends_in_4[:400]
skew_negative4 = ends_in_0[:1000] + ends_in_1[:800] + ends_in_2[:600] + ends_in_3[:400] + ends_in_4[:200]
no_4s = ends_in_0[:1000] + ends_in_1[:1000] + ends_in_2[:1000] + ends_in_3[:1000]

inverted = ends_in_0[:900] + ends_in_1[:950] + ends_in_2[:1000] + ends_in_3[:950] + ends_in_4[:900]
inverted2 = ends_in_0[:800] + ends_in_1[:900] + ends_in_2[:1000] + ends_in_3[:900] + ends_in_4[:800]
inverted3 = ends_in_0[:700] + ends_in_1[:850] + ends_in_2[:1000] + ends_in_3[:850] + ends_in_4[:700]
inverted4 = ends_in_0[:600] + ends_in_1[:800] + ends_in_2[:1000] + ends_in_3[:800] + ends_in_4[:600]
inverted5 = ends_in_0[:500] + ends_in_1[:750] + ends_in_2[:1000] + ends_in_3[:750] + ends_in_4[:500]

# %% [markdown]
# Run the next 2 cells to reset the lists

# %%
skews = []

skews.append(baseline)

skews.append(skew_positive)
skews.append(skew_positive2)
skews.append(skew_positive3)
skews.append(skew_positive4)
skews.append(no_0s)


skews.append(skew_negative)
skews.append(skew_negative2)
skews.append(skew_negative3)
skews.append(skew_negative4)
skews.append(no_4s)

skews.append(inverted)
skews.append(inverted2)
skews.append(inverted3)
skews.append(inverted4)
skews.append(inverted5)

# %%
for skew in skews:
    print(mean_of_skew(skew))
# Out:
# 2.0
# 2.111111111111111
# 2.25
# 2.4285714285714284
# 2.6666666666666665
# 2.5
# 1.8888888888888888
# 1.75
# 1.5714285714285714
# 1.3333333333333333
# 1.5
# 2.0
# 2.0
# 2.0
# 2.0
# 2.0

# %%
baseline[0][1]
# Out:
# 2

# %%
baseline[:2]
# Out:
# [([10058,
#    152,
#    46,
#    1410,
#    1,
#    172,
#    14,
#    1062,
#    1171,
#    171,
#    285,
#    37,
#    1,
#    361,
#    9286,
#    433,
#    37,
#    10059,
#    10060,
#    9,
#    4587,
#    33],
#   2),
#  ([132,
#    9,
#    1706,
#    37,
#    3925,
#    149,
#    26,
#    71,
#    279,
#    2231,
#    146,
#    15,
#    837,
#    3108,
#    526,
#    3926,
#    5,
#    461,
#    3927,
#    3928,
#    37,
#    1,
#    754,
#    3929,
#    33],
#   0)]

# %%
all_run_statistics = []

for skew in skews:
    stats_on_run = run_train_function(skew, baseline_dev, learning_rates, num_epochs)
    all_run_statistics.append(stats_on_run)
# Out:
# iter 0: train loss/sent=1.5834, time=0.19s
# iter 0: test acc=0.3064
# iter 10: train loss/sent=1.0656, time=0.17s
# iter 10: test acc=0.3784
# iter 20: train loss/sent=0.8650, time=0.17s
# iter 20: test acc=0.3848
# iter 30: train loss/sent=0.7437, time=0.17s
# iter 30: test acc=0.3904
# iter 40: train loss/sent=0.6601, time=0.17s
# iter 40: test acc=0.4024
# iter 50: train loss/sent=0.5978, time=0.19s
# iter 50: test acc=0.4040
# iter 60: train loss/sent=0.5488, time=0.19s
# iter 60: test acc=0.4000
# iter 70: train loss/sent=0.5089, time=0.19s
# iter 70: test acc=0.4032
# iter 80: train loss/sent=0.4753, time=0.18s
# iter 80: test acc=0.3960
# iter 90: train loss/sent=0.4466, time=0.20s
# iter 90: test acc=0.4008
# Average distance away from correct rating across all values, incorrect and correct:  0.9056
# Average distance away overall among all predictions:  -0.0048
# When wrong, the model was overly positive by:  1.4699738903394255
# When wrong, the model was overly negative by:  -1.5420054200542006
# Percent correct:  39.839999999999996
# Percent wrong:  60.160000000000004
# iter 0: train loss/sent=1.5946, time=0.19s
# iter 0: test acc=0.2960
# iter 10: train loss/sent=1.0620, time=0.17s
# iter 10: test acc=0.3720
# iter 20: train loss/sent=0.8557, time=0.16s
# iter 20: test acc=0.3808
# iter 30: train loss/sent=0.7317, time=0.16s
# iter 30: test acc=0.3864
# iter 40: train loss/sent=0.6463, time=0.16s
# iter 40: test acc=0.3872
# iter 50: train loss/sent=0.5832, time=0.17s
# iter 50: test acc=0.3888
# iter 60: train loss/sent=0.5338, time=0.16s
# iter 60: test acc=0.3888
# iter 70: train loss/sent=0.4933, time=0.16s
# iter 70: test acc=0.3888
# iter 80: train loss/sent=0.4598, time=0.17s
# iter 80: test acc=0.3896
# iter 90: train loss/sent=0.4308, time=0.16s
# iter 90: test acc=0.3888
# Average distance away from correct rating across all values, incorrect and correct:  0.9504
# Average distance away overall among all predictions:  0.1536
# When wrong, the model was overly positive by:  1.571753986332574
# When wrong, the model was overly negative by:  -1.5045317220543806
# Percent correct:  38.4
# Percent wrong:  61.6
# iter 0: train loss/sent=1.6120, time=0.14s
# iter 0: test acc=0.2280
# iter 10: train loss/sent=1.0540, time=0.14s
# iter 10: test acc=0.3496
# iter 20: train loss/sent=0.8436, time=0.14s
# iter 20: test acc=0.3504
# iter 30: train loss/sent=0.7179, time=0.15s
# iter 30: test acc=0.3656
# iter 40: train loss/sent=0.6321, time=0.15s
# iter 40: test acc=0.3712
# iter 50: train loss/sent=0.5690, time=0.15s
# iter 50: test acc=0.3728
# iter 60: train loss/sent=0.5193, time=0.15s
# iter 60: test acc=0.3720
# iter 70: train loss/sent=0.4793, time=0.16s
# iter 70: test acc=0.3776
# iter 80: train loss/sent=0.4460, time=0.15s
# iter 80: test acc=0.3808
# iter 90: train loss/sent=0.4172, time=0.15s
# iter 90: test acc=0.3768
# Average distance away from correct rating across all values, incorrect and correct:  0.992
# Average distance away overall among all predictions:  0.3376
# When wrong, the model was overly positive by:  1.7028688524590163
# When wrong, the model was overly negative by:  -1.4250871080139373
# Percent correct:  38.0
# Percent wrong:  62.0
# iter 0: train loss/sent=1.5755, time=0.14s
# iter 0: test acc=0.2384
# iter 10: train loss/sent=1.0380, time=0.14s
# iter 10: test acc=0.3112
# iter 20: train loss/sent=0.8246, time=0.13s
# iter 20: test acc=0.3328
# iter 30: train loss/sent=0.6978, time=0.15s
# iter 30: test acc=0.3352
# iter 40: train loss/sent=0.6113, time=0.13s
# iter 40: test acc=0.3432
# iter 50: train loss/sent=0.5483, time=0.11s
# iter 50: test acc=0.3480
# iter 60: train loss/sent=0.4993, time=0.11s
# iter 60: test acc=0.3520
# iter 70: train loss/sent=0.4595, time=0.14s
# iter 70: test acc=0.3552
# iter 80: train loss/sent=0.4264, time=0.13s
# iter 80: test acc=0.3552
# iter 90: train loss/sent=0.3982, time=0.12s
# iter 90: test acc=0.3560
# Average distance away from correct rating across all values, incorrect and correct:  1.064
# Average distance away overall among all predictions:  0.5136
# When wrong, the model was overly positive by:  1.7638640429338104
# When wrong, the model was overly negative by:  -1.3870967741935485
# Percent correct:  35.44
# Percent wrong:  64.56
# iter 0: train loss/sent=1.4874, time=0.11s
# iter 0: test acc=0.2488
# iter 10: train loss/sent=0.9885, time=0.11s
# iter 10: test acc=0.2760
# iter 20: train loss/sent=0.7810, time=0.10s
# iter 20: test acc=0.2952
# iter 30: train loss/sent=0.6578, time=0.09s
# iter 30: test acc=0.3000
# iter 40: train loss/sent=0.5748, time=0.10s
# iter 40: test acc=0.3112
# iter 50: train loss/sent=0.5146, time=0.13s
# iter 50: test acc=0.3072
# iter 60: train loss/sent=0.4677, time=0.13s
# iter 60: test acc=0.3096
# iter 70: train loss/sent=0.4299, time=0.11s
# iter 70: test acc=0.3168
# iter 80: train loss/sent=0.3985, time=0.11s
# iter 80: test acc=0.3160
# iter 90: train loss/sent=0.3720, time=0.10s
# iter 90: test acc=0.3136
# Average distance away from correct rating across all values, incorrect and correct:  1.2072
# Average distance away overall among all predictions:  0.804
# When wrong, the model was overly positive by:  1.9045454545454545
# When wrong, the model was overly negative by:  -1.2989690721649485
# Percent correct:  31.680000000000003
# Percent wrong:  68.32000000000001
# iter 0: train loss/sent=1.4052, time=0.14s
# iter 0: test acc=0.2792
# iter 10: train loss/sent=0.9291, time=0.15s
# iter 10: test acc=0.3192
# iter 20: train loss/sent=0.7527, time=0.13s
# iter 20: test acc=0.3360
# iter 30: train loss/sent=0.6460, time=0.15s
# iter 30: test acc=0.3392
# iter 40: train loss/sent=0.5728, time=0.14s
# iter 40: test acc=0.3416
# iter 50: train loss/sent=0.5182, time=0.14s
# iter 50: test acc=0.3512
# iter 60: train loss/sent=0.4758, time=0.14s
# iter 60: test acc=0.3472
# iter 70: train loss/sent=0.4412, time=0.16s
# iter 70: test acc=0.3536
# iter 80: train loss/sent=0.4118, time=0.14s
# iter 80: test acc=0.3528
# iter 90: train loss/sent=0.3870, time=0.14s
# iter 90: test acc=0.3504
# Average distance away from correct rating across all values, incorrect and correct:  0.9648
# Average distance away overall among all predictions:  0.3536
# When wrong, the model was overly positive by:  1.5344506517690875
# When wrong, the model was overly negative by:  -1.3840579710144927
# Percent correct:  34.96
# Percent wrong:  65.03999999999999
# iter 0: train loss/sent=1.5855, time=0.17s
# iter 0: test acc=0.2992
# iter 10: train loss/sent=1.0622, time=0.16s
# iter 10: test acc=0.3664
# iter 20: train loss/sent=0.8569, time=0.14s
# iter 20: test acc=0.3696
# iter 30: train loss/sent=0.7333, time=0.17s
# iter 30: test acc=0.3776
# iter 40: train loss/sent=0.6486, time=0.19s
# iter 40: test acc=0.3848
# iter 50: train loss/sent=0.5848, time=0.17s
# iter 50: test acc=0.3856
# iter 60: train loss/sent=0.5359, time=0.16s
# iter 60: test acc=0.3904
# iter 70: train loss/sent=0.4956, time=0.16s
# iter 70: test acc=0.3872
# iter 80: train loss/sent=0.4620, time=0.17s
# iter 80: test acc=0.3864
# iter 90: train loss/sent=0.4330, time=0.16s
# iter 90: test acc=0.3904
# Average distance away from correct rating across all values, incorrect and correct:  0.9184
# Average distance away overall among all predictions:  -0.0752
# When wrong, the model was overly positive by:  1.4398907103825136
# When wrong, the model was overly negative by:  -1.544776119402985
# Percent correct:  38.56
# Percent wrong:  61.44
# iter 0: train loss/sent=1.5774, time=0.14s
# iter 0: test acc=0.2568
# iter 10: train loss/sent=1.0526, time=0.13s
# iter 10: test acc=0.3504
# iter 20: train loss/sent=0.8426, time=0.14s
# iter 20: test acc=0.3520
# iter 30: train loss/sent=0.7170, time=0.14s
# iter 30: test acc=0.3656
# iter 40: train loss/sent=0.6311, time=0.14s
# iter 40: test acc=0.3696
# iter 50: train loss/sent=0.5677, time=0.14s
# iter 50: test acc=0.3664
# iter 60: train loss/sent=0.5182, time=0.14s
# iter 60: test acc=0.3696
# iter 70: train loss/sent=0.4779, time=0.17s
# iter 70: test acc=0.3704
# iter 80: train loss/sent=0.4446, time=0.14s
# iter 80: test acc=0.3720
# iter 90: train loss/sent=0.4160, time=0.14s
# iter 90: test acc=0.3712
# Average distance away from correct rating across all values, incorrect and correct:  0.984
# Average distance away overall among all predictions:  -0.2032
# When wrong, the model was overly positive by:  1.4144927536231884
# When wrong, the model was overly negative by:  -1.6525612472160356
# Percent correct:  36.480000000000004
# Percent wrong:  63.519999999999996
# iter 0: train loss/sent=1.5543, time=0.13s
# iter 0: test acc=0.2192
# iter 10: train loss/sent=1.0297, time=0.12s
# iter 10: test acc=0.3304
# iter 20: train loss/sent=0.8169, time=0.12s
# iter 20: test acc=0.3384
# iter 30: train loss/sent=0.6908, time=0.13s
# iter 30: test acc=0.3360
# iter 40: train loss/sent=0.6051, time=0.13s
# iter 40: test acc=0.3376
# iter 50: train loss/sent=0.5420, time=0.13s
# iter 50: test acc=0.3416
# iter 60: train loss/sent=0.4932, time=0.12s
# iter 60: test acc=0.3456
# iter 70: train loss/sent=0.4538, time=0.14s
# iter 70: test acc=0.3432
# iter 80: train loss/sent=0.4209, time=0.13s
# iter 80: test acc=0.3488
# iter 90: train loss/sent=0.3932, time=0.13s
# iter 90: test acc=0.3480
# Average distance away from correct rating across all values, incorrect and correct:  1.0512
# Average distance away overall among all predictions:  -0.456
# When wrong, the model was overly positive by:  1.3726937269372694
# When wrong, the model was overly negative by:  -1.7444444444444445
# Percent correct:  35.120000000000005
# Percent wrong:  64.88000000000001
# iter 0: train loss/sent=1.5089, time=0.13s
# iter 0: test acc=0.2080
# iter 10: train loss/sent=0.9909, time=0.11s
# iter 10: test acc=0.2768
# iter 20: train loss/sent=0.7791, time=0.11s
# iter 20: test acc=0.2872
# iter 30: train loss/sent=0.6543, time=0.09s
# iter 30: test acc=0.2928
# iter 40: train loss/sent=0.5708, time=0.09s
# iter 40: test acc=0.2984
# iter 50: train loss/sent=0.5098, time=0.11s
# iter 50: test acc=0.3040
# iter 60: train loss/sent=0.4628, time=0.11s
# iter 60: test acc=0.3096
# iter 70: train loss/sent=0.4250, time=0.09s
# iter 70: test acc=0.3120
# iter 80: train loss/sent=0.3932, time=0.09s
# iter 80: test acc=0.3096
# iter 90: train loss/sent=0.3667, time=0.11s
# iter 90: test acc=0.3120
# Average distance away from correct rating across all values, incorrect and correct:  1.1904
# Average distance away overall among all predictions:  -0.768
# When wrong, the model was overly positive by:  1.2941176470588236
# When wrong, the model was overly negative by:  -1.880184331797235
# Percent correct:  31.6
# Percent wrong:  68.4
# iter 0: train loss/sent=1.4203, time=0.17s
# iter 0: test acc=0.2648
# iter 10: train loss/sent=0.9439, time=0.19s
# iter 10: test acc=0.3432
# iter 20: train loss/sent=0.7656, time=0.14s
# iter 20: test acc=0.3440
# iter 30: train loss/sent=0.6571, time=0.14s
# iter 30: test acc=0.3376
# iter 40: train loss/sent=0.5826, time=0.16s
# iter 40: test acc=0.3424
# iter 50: train loss/sent=0.5272, time=0.14s
# iter 50: test acc=0.3392
# iter 60: train loss/sent=0.4839, time=0.14s
# iter 60: test acc=0.3376
# iter 70: train loss/sent=0.4486, time=0.14s
# iter 70: test acc=0.3408
# iter 80: train loss/sent=0.4191, time=0.13s
# iter 80: test acc=0.3456
# iter 90: train loss/sent=0.3940, time=0.13s
# iter 90: test acc=0.3376
# Average distance away from correct rating across all values, incorrect and correct:  0.976
# Average distance away overall among all predictions:  -0.3216
# When wrong, the model was overly positive by:  1.315112540192926
# When wrong, the model was overly negative by:  -1.5747572815533981
# Percent correct:  33.92
# Percent wrong:  66.08000000000001
# iter 0: train loss/sent=1.5907, time=0.22s
# iter 0: test acc=0.3136
# iter 10: train loss/sent=1.0692, time=0.16s
# iter 10: test acc=0.3696
# iter 20: train loss/sent=0.8650, time=0.16s
# iter 20: test acc=0.3784
# iter 30: train loss/sent=0.7419, time=0.17s
# iter 30: test acc=0.3864
# iter 40: train loss/sent=0.6572, time=0.17s
# iter 40: test acc=0.3920
# iter 50: train loss/sent=0.5939, time=0.17s
# iter 50: test acc=0.3896
# iter 60: train loss/sent=0.5443, time=0.17s
# iter 60: test acc=0.3904
# iter 70: train loss/sent=0.5037, time=0.17s
# iter 70: test acc=0.3968
# iter 80: train loss/sent=0.4701, time=0.16s
# iter 80: test acc=0.3928
# iter 90: train loss/sent=0.4413, time=0.17s
# iter 90: test acc=0.3936
# Average distance away from correct rating across all values, incorrect and correct:  0.9144
# Average distance away overall among all predictions:  0.0424
# When wrong, the model was overly positive by:  1.4875621890547264
# When wrong, the model was overly negative by:  -1.5138888888888888
# Percent correct:  39.04
# Percent wrong:  60.96
# iter 0: train loss/sent=1.5907, time=0.16s
# iter 0: test acc=0.2856
# iter 10: train loss/sent=1.0700, time=0.14s
# iter 10: test acc=0.3640
# iter 20: train loss/sent=0.8639, time=0.17s
# iter 20: test acc=0.3688
# iter 30: train loss/sent=0.7393, time=0.16s
# iter 30: test acc=0.3696
# iter 40: train loss/sent=0.6539, time=0.16s
# iter 40: test acc=0.3784
# iter 50: train loss/sent=0.5907, time=0.16s
# iter 50: test acc=0.3760
# iter 60: train loss/sent=0.5407, time=0.16s
# iter 60: test acc=0.3800
# iter 70: train loss/sent=0.5004, time=0.16s
# iter 70: test acc=0.3824
# iter 80: train loss/sent=0.4664, time=0.16s
# iter 80: test acc=0.3824
# iter 90: train loss/sent=0.4376, time=0.17s
# iter 90: test acc=0.3840
# Average distance away from correct rating across all values, incorrect and correct:  0.9352
# Average distance away overall among all predictions:  0.0712
# When wrong, the model was overly positive by:  1.523002421307506
# When wrong, the model was overly negative by:  -1.5083798882681565
# Percent correct:  38.32
# Percent wrong:  61.68
# iter 0: train loss/sent=1.5934, time=0.14s
# iter 0: test acc=0.2536
# iter 10: train loss/sent=1.0697, time=0.16s
# iter 10: test acc=0.3440
# iter 20: train loss/sent=0.8608, time=0.13s
# iter 20: test acc=0.3600
# iter 30: train loss/sent=0.7352, time=0.16s
# iter 30: test acc=0.3632
# iter 40: train loss/sent=0.6488, time=0.14s
# iter 40: test acc=0.3592
# iter 50: train loss/sent=0.5851, time=0.16s
# iter 50: test acc=0.3680
# iter 60: train loss/sent=0.5350, time=0.14s
# iter 60: test acc=0.3712
# iter 70: train loss/sent=0.4946, time=0.12s
# iter 70: test acc=0.3672
# iter 80: train loss/sent=0.4608, time=0.16s
# iter 80: test acc=0.3712
# iter 90: train loss/sent=0.4318, time=0.14s
# iter 90: test acc=0.3672
# Average distance away from correct rating across all values, incorrect and correct:  0.9416
# Average distance away overall among all predictions:  0.0504
# When wrong, the model was overly positive by:  1.486810551558753
# When wrong, the model was overly negative by:  -1.4853333333333334
# Percent correct:  36.64
# Percent wrong:  63.36000000000001
# iter 0: train loss/sent=1.5905, time=0.12s
# iter 0: test acc=0.2344
# iter 10: train loss/sent=1.0682, time=0.12s
# iter 10: test acc=0.3224
# iter 20: train loss/sent=0.8569, time=0.12s
# iter 20: test acc=0.3352
# iter 30: train loss/sent=0.7300, time=0.14s
# iter 30: test acc=0.3528
# iter 40: train loss/sent=0.6434, time=0.12s
# iter 40: test acc=0.3480
# iter 50: train loss/sent=0.5790, time=0.14s
# iter 50: test acc=0.3536
# iter 60: train loss/sent=0.5290, time=0.13s
# iter 60: test acc=0.3552
# iter 70: train loss/sent=0.4882, time=0.12s
# iter 70: test acc=0.3608
# iter 80: train loss/sent=0.4544, time=0.13s
# iter 80: test acc=0.3632
# iter 90: train loss/sent=0.4253, time=0.12s
# iter 90: test acc=0.3608
# Average distance away from correct rating across all values, incorrect and correct:  0.9488
# Average distance away overall among all predictions:  0.0608
# When wrong, the model was overly positive by:  1.5095693779904307
# When wrong, the model was overly negative by:  -1.4605263157894737
# Percent correct:  36.16
# Percent wrong:  63.839999999999996
# iter 0: train loss/sent=1.5581, time=0.13s
# iter 0: test acc=0.2208
# iter 10: train loss/sent=1.0566, time=0.11s
# iter 10: test acc=0.2968
# iter 20: train loss/sent=0.8449, time=0.13s
# iter 20: test acc=0.3208
# iter 30: train loss/sent=0.7176, time=0.13s
# iter 30: test acc=0.3360
# iter 40: train loss/sent=0.6310, time=0.11s
# iter 40: test acc=0.3400
# iter 50: train loss/sent=0.5671, time=0.11s
# iter 50: test acc=0.3360
# iter 60: train loss/sent=0.5173, time=0.13s
# iter 60: test acc=0.3328
# iter 70: train loss/sent=0.4765, time=0.13s
# iter 70: test acc=0.3336
# iter 80: train loss/sent=0.4433, time=0.13s
# iter 80: test acc=0.3416
# iter 90: train loss/sent=0.4146, time=0.13s
# iter 90: test acc=0.3424
# Average distance away from correct rating across all values, incorrect and correct:  0.96
# Average distance away overall among all predictions:  0.0224
# When wrong, the model was overly positive by:  1.4413145539906103
# When wrong, the model was overly negative by:  -1.468671679197995
# Percent correct:  34.0
# Percent wrong:  66.0

# %%
all_run_statistics
# Out:
# [{(0.0005, 100): (0.9056,
#    -0.0048,
#    1.4699738903394255,
#    -1.5420054200542006,
#    39.839999999999996,
#    60.160000000000004)},
#  {(0.0005, 100): (0.9504,
#    0.1536,
#    1.571753986332574,
#    -1.5045317220543806,
#    38.4,
#    61.6)},
#  {(0.0005, 100): (0.992,
#    0.3376,
#    1.7028688524590163,
#    -1.4250871080139373,
#    38.0,
#    62.0)},
#  {(0.0005, 100): (1.064,
#    0.5136,
#    1.7638640429338104,
#    -1.3870967741935485,
#    35.44,
#    64.56)},
#  {(0.0005, 100): (1.2072,
#    0.804,
#    1.9045454545454545,
#    -1.2989690721649485,
#    31.680000000000003,
#    68.32000000000001)},
#  {(0.0005, 100): (0.9648,
#    0.3536,
#    1.5344506517690875,
#    -1.3840579710144927,
#    34.96,
#    65.03999999999999)},
#  {(0.0005, 100): (0.9184,
#    -0.0752,
#    1.4398907103825136,
#    -1.544776119402985,
#    38.56,
#    61.44)},
#  {(0.0005, 100): (0.984,
#    -0.2032,
#    1.4144927536231884,
#    -1.6525612472160356,
#    36.480000000000004,
#    63.519999999999996)},
#  {(0.0005, 100): (1.0512,
#    -0.456,
#    1.3726937269372694,
#    -1.7444444444444445,
#    35.120000000000005,
#    64.88000000000001)},
#  {(0.0005, 100): (1.1904,
#    -0.768,
#    1.2941176470588236,
#    -1.880184331797235,
#    31.6,
#    68.4)},
#  {(0.0005, 100): (0.976,
#    -0.3216,
#    1.315112540192926,
#    -1.5747572815533981,
#    33.92,
#    66.08000000000001)},
#  {(0.0005, 100): (0.9144,
#    0.0424,
#    1.4875621890547264,
#    -1.5138888888888888,
#    39.04,
#    60.96)},
#  {(0.0005, 100): (0.9352,
#    0.0712,
#    1.523002421307506,
#    -1.5083798882681565,
#    38.32,
#    61.68)},
#  {(0.0005, 100): (0.9416,
#    0.0504,
#    1.486810551558753,
#    -1.4853333333333334,
#    36.64,
#    63.36000000000001)},
#  {(0.0005, 100): (0.9488,
#    0.0608,
#    1.5095693779904307,
#    -1.4605263157894737,
#    36.16,
#    63.839999999999996)},
#  {(0.0005, 100): (0.96,
#    0.0224,
#    1.4413145539906103,
#    -1.468671679197995,
#    34.0,
#    66.0)}]
